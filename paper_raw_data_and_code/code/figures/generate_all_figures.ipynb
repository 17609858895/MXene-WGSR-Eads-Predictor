# %% [markdown]
# # MXene adsorption-energy paper figures
#
# Run the next cell to regenerate Fig.1-Fig.8. The script writes PNG and PDF outputs into `Fig01`-`Fig08`. Fig.2-Fig.8 use Arial, unified colors, bold axes, and no in-figure panel titles.

# %%
from pathlib import Path
import runpy

script = Path.cwd() / 'generate_all_figures.py'
if not script.exists():
    script = Path('新论文绘图_吸附能主线/Fig00_scripts/generate_all_figures.py')

runpy.run_path(str(script), run_name='__main__')
